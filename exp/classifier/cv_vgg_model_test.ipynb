# %%
from tensorflow.keras.models import load_model
import os
import matplotlib.pyplot as plt
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.vgg19 import preprocess_input
import numpy as np
import cv2

# %%
model = load_model("cv_vgg_model.h5")

# %%
path = "../datasets/tests"
i = 0

for img in os.listdir(path):
    img = image.load_img(path+"/"+img,target_size=(290, 290))
    plt.imshow(img)
    plt.show()
    
    x = image.img_to_array(img)
    x = np.expand_dims(x,axis=0)
    images = np.vstack([x])
    pred = model.predict(images,batch_size=1) 
    if pred[0][0] > 0.5:
        category = "Blurred"
    elif pred[0][1] > 0.5:
        category = "Original"
    elif pred[0][2] > 0.5:
        category = "Skewed"
        
    print(category)
# Out:
# 1/1 [==============================] - 0s 251ms/step
# Original
# 1/1 [==============================] - 0s 282ms/step
# Skewed
# 1/1 [==============================] - 0s 293ms/step
# Skewed
# 1/1 [==============================] - 0s 282ms/step
# Skewed
# 1/1 [==============================] - 0s 267ms/step
# Original
# 1/1 [==============================] - 0s 329ms/step
# Skewed
# 1/1 [==============================] - 0s 345ms/step
# Skewed
# 1/1 [==============================] - 0s 408ms/step
# Skewed
# 1/1 [==============================] - 0s 392ms/step
# Original
# 1/1 [==============================] - 0s 352ms/step
# Skewed
# 1/1 [==============================] - 0s 424ms/step
# Skewed
# 1/1 [==============================] - 0s 439ms/step
# Skewed
# 1/1 [==============================] - 0s 345ms/step
# Original
# 1/1 [==============================] - 0s 314ms/step
# Skewed
# 1/1 [==============================] - 0s 282ms/step
# Skewed
# 1/1 [==============================] - 0s 314ms/step
# Skewed
# 1/1 [==============================] - 0s 298ms/step
# Original
# 1/1 [==============================] - 0s 282ms/step
# Skewed
# 1/1 [==============================] - 0s 282ms/step
# Skewed
# 1/1 [==============================] - 0s 408ms/step
# Skewed
# 1/1 [==============================] - 0s 314ms/step
# Original
# 1/1 [==============================] - 0s 300ms/step
# Original
# 1/1 [==============================] - 0s 298ms/step
# Skewed
# 1/1 [==============================] - 0s 298ms/step
# Skewed
# 1/1 [==============================] - 0s 282ms/step
# Original
# 1/1 [==============================] - 0s 316ms/step
# Skewed
# 1/1 [==============================] - 0s 275ms/step
# Skewed
# 1/1 [==============================] - 0s 298ms/step
# Skewed
# 1/1 [==============================] - 0s 282ms/step
# Original
# 1/1 [==============================] - 0s 266ms/step
# Skewed
# 1/1 [==============================] - 0s 298ms/step
# Skewed
# 1/1 [==============================] - 0s 298ms/step
# Skewed
# 1/1 [==============================] - 0s 298ms/step
# Original
# 1/1 [==============================] - 0s 329ms/step
# Skewed
# 1/1 [==============================] - 0s 408ms/step
# Skewed
# 1/1 [==============================] - 0s 426ms/step
# Skewed
# 1/1 [==============================] - 0s 384ms/step
# Skewed
# 1/1 [==============================] - 0s 377ms/step
# Skewed
# 1/1 [==============================] - 0s 424ms/step
# Skewed
# 1/1 [==============================] - 0s 453ms/step
# Skewed
